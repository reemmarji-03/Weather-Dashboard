# %%
import requests
from backend import API_KEY

url = f'https://api.openweathermap.org/data/2.5/forecast?q=beirut&appid={API_KEY}'
response = requests.get(url)
data = response.json()
filterd_data = data['list']

print(filterd_data)
print(len(filterd_data))
# Out:
# [{'dt': 1733421600, 'main': {'temp': 291.61, 'feels_like': 291.23, 'temp_min': 291.61, 'temp_max': 291.71, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 1014, 'humidity': 66, 'temp_kf': -0.1}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'clouds': {'all': 13}, 'wind': {'speed': 3.86, 'deg': 13, 'gust': 3.69}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2024-12-05 18:00:00'}, {'dt': 1733432400, 'main': {'temp': 291.76, 'feels_like': 291.14, 'temp_min': 291.76, 'temp_max': 291.86, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 1015, 'humidity': 56, 'temp_kf': -0.1}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 7}, 'wind': {'speed': 1.83, 'deg': 29, 'gust': 2.15}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2024-12-05 21:00:00'}, {'dt': 1733443200, 'main': {'temp': 291.66, 'feels_like': 290.77, 'temp_min': 291.66, 'temp_max': 291.66, 'press
# ...
